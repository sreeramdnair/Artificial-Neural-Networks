# %% [markdown]
# <a href="https://colab.research.google.com/github/sreeramdnair/Artificial-Neural-Networks/blob/main/malaria_cell_classification_using_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install kaggle

# %%
! mkdir ~/.kaggle

# %%
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets download iarunava/cell-images-for-detecting-malaria
# Out:
# ...
# 100% 675M/675M [00:05<00:00, 125MB/s]
# 100% 675M/675M [00:05<00:00, 122MB/s]

# %%
! unzip /content/cell-images-for-detecting-malaria.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102428_cell_116.png
#   inflating: cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102428_cell_118.png
#   inflating: cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102428_cell_126.png
#   inflating: cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102428_cell_134.png
#   inflating: cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102428_cell_141.png
#   inflating: cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102428_cell_168.png
#   inflating: cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102428_cell_175.png
#   inflating: cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102428_cell_183.png
#   inflating: cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102428_cell_221.png
#   inflating: cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102428_cell_222.png
# ...

# %%
pip install tensorflow

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Activation, Dropout, Flatten, Dense,Conv2D, MaxPooling2D
import os
import cv2
from PIL import Image
import numpy as np

# %%
values=[]
target=[]
infected_images=os.listdir("/content/cell_images/Parasitized")[0:1000]
uninfected_images=os.listdir("/content/cell_images/Uninfected")[0:1000]

for image_name in infected_images:
  image= cv2.imread("/content/cell_images/Parasitized/"+ image_name)
  print("/content/cell_images/Parasitized/"+ image_name)
  image= Image.fromarray(image,'RGB')
  image=image.resize((64,64))
  values.append(np.array(image))
  target.append(1)

for image_name in uninfected_images:
  image= cv2.imread("/content/cell_images/Uninfected/"+ image_name)
  image= Image.fromarray(image,'RGB')
  image=image.resize((64,64))
  values.append(np.array(image))
  target.append(0)
print(len(values))
# Out:
# /content/cell_images/Parasitized/C129P90ThinF_IMG_20151004_134636_cell_8.png
# /content/cell_images/Parasitized/C81P42ThinF_IMG_20150817_120712_cell_157.png
# /content/cell_images/Parasitized/C183P144NThinF_IMG_20151201_224458_cell_127.png
# /content/cell_images/Parasitized/C59P20thinF_IMG_20150803_111244_cell_169.png
# /content/cell_images/Parasitized/C59P20thinF_IMG_20150803_113430_cell_3.png
# /content/cell_images/Parasitized/C172P133ThinF_IMG_20151119_155307_cell_262.png
# /content/cell_images/Parasitized/C115P76ThinF_IMG_20150930_161825_cell_220.png
# /content/cell_images/Parasitized/C51AP12thinF_IMG_20150724_154243_cell_116.png
# /content/cell_images/Parasitized/C179P140ThinF_IMG_20151127_153350_cell_179.png
# /content/cell_images/Parasitized/C129P90ThinF_IMG_20151004_133703_cell_90.png
# /content/cell_images/Parasitized/C39P4thinF_original_IMG_20150622_114609_cell_6.png
# /content/cell_images/Parasitized/C39P4thinF_original_IMG_20150622_113632_cell_8.png
# ...

# %%
values = np.array(values)
target = np.array(target)
print(len(values),len(target))
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(values,target,test_size=0.2,random_state = 0)
print(len(x_test),len(y_test))
# Out:
# 2000 2000
# 400 400

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(64,64,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3), kernel_initializer = 'he_uniform'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3), kernel_initializer = 'he_uniform'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(1))
model.add(Activation('sigmoid')) 

model.compile(loss='binary_crossentropy',
              optimizer='adam',             
              metrics=['accuracy'])

# %%
cnn = model.fit(x_train,y_train, batch_size = 64, verbose = 1,epochs = 50, validation_data=(x_test,y_test),shuffle = False)
# Out:
# Epoch 1/50
# 25/25 [==============================] - 8s 303ms/step - loss: 0.6145 - accuracy: 0.6169 - val_loss: 0.6215 - val_accuracy: 0.7075
# Epoch 2/50
# 25/25 [==============================] - 8s 302ms/step - loss: 0.6253 - accuracy: 0.6106 - val_loss: 0.6122 - val_accuracy: 0.7025
# Epoch 3/50
# 25/25 [==============================] - 8s 303ms/step - loss: 0.6224 - accuracy: 0.6031 - val_loss: 0.5955 - val_accuracy: 0.6925
# Epoch 4/50
# 25/25 [==============================] - 8s 306ms/step - loss: 0.6223 - accuracy: 0.5675 - val_loss: 0.5742 - val_accuracy: 0.7200
# Epoch 5/50
# 25/25 [==============================] - 8s 306ms/step - loss: 0.5979 - accuracy: 0.6031 - val_loss: 0.5817 - val_accuracy: 0.7025
# Epoch 6/50
# 25/25 [==============================] - 8s 306ms/step - loss: 0.5965 - accuracy: 0.6425 - val_loss: 0.5666 - val_accuracy: 0.7200
# Epoch 7/50
# ...

# %%
# Out:
# 13/13 [==============================] - 1s 41ms/step - loss: 0.9478 - accuracy: 0.9250
# Accuracy =  92.5000011920929 %
